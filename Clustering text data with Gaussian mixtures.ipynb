# %%
import pandas as pd                                            # see below for install instruction
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse import spdiags
from scipy.stats import multivariate_normal
from copy import deepcopy
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import normalize

# %%
wiki = pd.read_csv('people_wiki.csv').head(5000)

# %%
wiki
# Out:
#                                                     URI  \
# 0           <http://dbpedia.org/resource/Digby_Morrell>
# 1          <http://dbpedia.org/resource/Alfred_J._Lewy>
# 2           <http://dbpedia.org/resource/Harpdog_Brown>
# 3     <http://dbpedia.org/resource/Franz_Rottensteiner>
# 4                  <http://dbpedia.org/resource/G-Enka>
# 5           <http://dbpedia.org/resource/Sam_Henderson>
# 6           <http://dbpedia.org/resource/Aaron_LaCrate>
# 7         <http://dbpedia.org/resource/Trevor_Ferguson>
# 8            <http://dbpedia.org/resource/Grant_Nelson>
# 9            <http://dbpedia.org/resource/Cathy_Caruth>
# 10           <http://dbpedia.org/resource/Sophie_Crumb>
# 11          <http://dbpedia.org/resource/Jenn_Ashworth>
# 12       <http://dbpedia.org/resource/Jonathan_Hoefler>
# 13    <http://dbpedia.org/resource/Anthony_Gueterboc...
# 14     <http://dbpedia.org/resource/David_Chernushenko>
# 15         <http://dbpedia.org/resource/Joerg_Steineck>
# 16         <http://dbpedia.org/resource/Andrew_Pinsent>
# 17    <http://dbpedia.org/resource/Paddy_Dunne_(Gael...
# 18      <http://dbpedia.org/resource/Alexandros_Mouzas>
# 19    <http://dbpedia.org/resource/John_Angus_Campbell>
# 20         <http://dbpedia.org/resource/Chris_Batstone>
# 21          <http://dbpedia.org/resource/Ceiron_Thomas>
# 22           <http://dbpedia.org/resource/Adel_Sellimi>
# 23          <http://dbpedia.org/resource/Faith_Soloway>
# 24           <http://dbpedia.org/resource/Tom_Jennings>
# 25            <http://dbpedia.org/resource/Vic_Stasiuk>
# 26        <http://dbpedia.org/resource/Anthony_Caruana>
# 27    <http://dbpedia.org/resource/Ian_Mitchell_(aut...
# 28           <http://dbpedia.org/resource/Leon_Hapgood>
# 29           <http://dbpedia.org/resource/Emily_Osment>
# ...                                                 ...
# 4970     <http://dbpedia.org/resource/Stepan_Pasicznyk>
# 4971  <http://dbpedia.org/resource/Donncha_%C3%93_D%...
# 4972         <http://dbpedia.org/resource/Sean_Grassie>
# 4973          <http://dbpedia.org/resource/Bubby_Lyons>
# 4974         <http://dbpedia.org/resource/Simone_Sello>
# 4975        <http://dbpedia.org/resource/Mohamed_Harbi>
# 4976  <http://dbpedia.org/resource/Glenn_Moore_(soft...
# 4977          <http://dbpedia.org/resource/John_Callen>
# 4978       <http://dbpedia.org/resource/Raffi_Armenian>
# 4979    <http://dbpedia.org/resource/Marcus_Dillistone>
# 4980  <http://dbpedia.org/resource/Petar_Georgiev-Ka...
# 4981          <http://dbpedia.org/resource/Ted_Ramirez>
# 4982           <http://dbpedia.org/resource/Warren_Ham>
# 4983          <http://dbpedia.org/resource/Levi_Tafari>
# 4984         <http://dbpedia.org/resource/Phil_Chapple>
# 4985  <http://dbpedia.org/resource/Marjorie_W._Sharmat>
# 4986      <http://dbpedia.org/resource/Hasse_Mattisson>
# 4987              <http://dbpedia.org/resource/Yunizar>
# 4988         <http://dbpedia.org/resource/Kenny_Miller>
# 4989     <http://dbpedia.org/resource/Jonathan_Hancock>
# 4990  <http://dbpedia.org/resource/Radoman_Bo%C5%BEo...
# 4991     <http://dbpedia.org/resource/Sudhir_Choudhrie>
# 4992        <http://dbpedia.org/resource/David_Donnell>
# 4993  <http://dbpedia.org/resource/Jeff_Reed_(baseba...
# 4994  <http://dbpedia.org/resource/John_McKay_(direc...
# 4995       <http://dbpedia.org/resource/Irena_Pantelic>
# 4996        <http://dbpedia.org/resource/Jerem%C3%ADas>
# 4997        <http://dbpedia.org/resource/Avraham_Eilat>
# 4998        <http://dbpedia.org/resource/Blythe_Bohnen>
# 4999          <http://dbpedia.org/resource/Raed_Jarrar>
#
#                                          name  \
# 0                               Digby Morrell
# 1                              Alfred J. Lewy
# 2                               Harpdog Brown
# 3                         Franz Rottensteiner
# 4                                      G-Enka
# 5                               Sam Henderson
# 6                               Aaron LaCrate
# 7                             Trevor Ferguson
# 8                                Grant Nelson
# 9                                Cathy Caruth
# 10                               Sophie Crumb
# 11                              Jenn Ashworth
# 12                           Jonathan Hoefler
# 13    Anthony Gueterbock, 18th Baron Berkeley
# 14                         David Chernushenko
# 15                             Joerg Steineck
# 16                             Andrew Pinsent
# 17            Paddy Dunne (Gaelic footballer)
# 18                          Alexandros Mouzas
# 19                        John Angus Campbell
# 20                             Chris Batstone
# 21                              Ceiron Thomas
# 22                               Adel Sellimi
# 23                              Faith Soloway
# 24                               Tom Jennings
# 25                                Vic Stasiuk
# 26                            Anthony Caruana
# 27                      Ian Mitchell (author)
# 28                               Leon Hapgood
# 29                               Emily Osment
# ...                                       ...
# 4970                         Stepan Pasicznyk
# 4971              Donncha %C3%93 D%C3%BAlaing
# 4972                             Sean Grassie
# 4973                              Bubby Lyons
# 4974                             Simone Sello
# 4975                            Mohamed Harbi
# 4976                   Glenn Moore (softball)
# 4977                              John Callen
# 4978                           Raffi Armenian
# 4979                        Marcus Dillistone
# 4980                    Petar Georgiev-Kalica
# 4981                              Ted Ramirez
# 4982                               Warren Ham
# 4983                              Levi Tafari
# 4984                             Phil Chapple
# 4985                      Marjorie W. Sharmat
# 4986                          Hasse Mattisson
# 4987                                  Yunizar
# 4988                             Kenny Miller
# 4989                         Jonathan Hancock
# 4990                Radoman Bo%C5%BEovi%C4%87
# 4991                         Sudhir Choudhrie
# 4992                            David Donnell
# 4993                     Jeff Reed (baseball)
# 4994                    John McKay (director)
# 4995                           Irena Pantelic
# 4996                            Jerem%C3%ADas
# 4997                            Avraham Eilat
# 4998                            Blythe Bohnen
# 4999                              Raed Jarrar
#
#                                                    text
# 0     digby morrell born 10 october 1979 is a former...
# 1     alfred j lewy aka sandy lewy graduated from un...
# 2     harpdog brown is a singer and harmonica player...
# 3     franz rottensteiner born in waidmannsfeld lowe...
# 4     henry krvits born 30 december 1974 in tallinn ...
# 5     sam henderson born october 18 1969 is an ameri...
# 6     aaron lacrate is an american music producer re...
# 7     trevor ferguson aka john farrow born 11 novemb...
# 8     grant nelson born 27 april 1971 in london also...
# 9     cathy caruth born 1955 is frank h t rhodes pro...
# 10    sophia violet sophie crumb born september 27 1...
# 11    jenn ashworth is an english writer she was bor...
# 12    jonathan hoefler born august 22 1970 is an ame...
# 13    anthony fitzhardinge gueterbock 18th baron ber...
# 14    david chernushenko born june 1963 in calgary a...
# 15    joerg steineck is a german filmmaker editor an...
# 16    fr andrew pinsent born 19 august 1966 is resea...
# 17    paddy dunne was a gaelic football player from ...
# 18    alexandros mouzas born 1962 is a greek compose...
# 19    john angus campbell born march 10 1942 in port...
# 20    chris batstone was the 20002002 lead singer of...
# 21    ceiron thomas born 23 october 1983 is a welsh ...
# 22    adel sellimi arabic was born on 16 november 19...
# 23    faith soloway born march 28 1964 is an america...
# 24    tom jennings born 1955 as thomas daniel jennin...
# 25    victor john stasiuk born may 23 1929 is a reti...
# 26    anthony caruana born 2 january 1968 is a melbo...
# 27    ian mitchell is a scottish author who grew up ...
# 28    leon duane hapgood born 7 august 1979is an eng...
# 29    emily jordan osment born march 10 1992 is an a...
# ...                                                 ...
# 4970  stepan pasicznyk is a british born musician so...
# 4971  donncha dlaing is a veteran irish broadcaster ...
# 4972  sean grassie is a canadian curler from winnipe...
# 4973  edward paul bubby lyons born june 16 1929 in h...
# 4974  simone sello born july 4 1968 is an italian bo...
# 4975  mohamed harbi born 1933 is an algerian histori...
# 4976  glenn moore is the head coach of the baylor so...
# 4977  john callen born november 4 1946 is an english...
# 4978  raffi armenian cm born june 4 1942 is an egypt...
# 4979  marcus dillistone is a british film directora ...
# 4980  petar georgievkalica macedonian born november ...
# 4981  ted ramrez is tucsons official troubadour as p...
# 4982  warren ham born 1957 is a vocalist saxophonist...
# 4983  levi tafari was born and raised in the city of...
# 4984  phil chapple born 26 november 1966 is an engli...
# 4985  marjorie weinman sharmat born november 12 1928...
# 4986  hans hasse mattisson born august 29 1972 in ma...
# 4987  yunizar born june 1971 is a prominent indonesi...
# 4988  kenneth kenny miller born 23 december 1979 is ...
# 4989  jonathan bruce hancock is the founder of the j...
# 4990  radoman boovi serbian born 13 january 1953 in ...
# 4991  sudhir choudhrie is an indianborn london resid...
# 4992  david donnellborn 13 october 1939 in st marys ...
# 4993  jeffrey scott reed born november 12 1962 in jo...
# 4994  john mckay is a scottish film and television d...
# 4995  irena arkesteijnpantelic born 1981 rotterdam i...
# 4996  carlos eduardo lpez avila better known under h...
# 4997  avraham eilat hebrew born 1939 in tel aviv is ...
# 4998  blythe bohnen b evanston illinois 1940 is an a...
# 4999  raed jarrar arabic is an arabamerican architec...
#
# [5000 rows x 3 columns]

# %%
def load_sparse_csr(filename):
    loader = np.load(filename)
    data = loader['data']
    indices = loader['indices']
    indptr = loader['indptr']
    shape = loader['shape']
    
    return csr_matrix( (data, indices, indptr), shape)

tf_idf = load_sparse_csr('4_tf_idf.npz')

# %%
import json
with open('4_map_index_to_word.json') as index_word_file:
    map_index_to_word = json.load(index_word_file)

# %%
map_index_to_word
# Out:
# {u'sundayswadsworth': 37318,
#  u'verplank': 46431,
#  u'damfunk': 23253,
#  u'anyer': 62437,
#  u'sonja': 37922,
#  u'degussa': 33295,
#  u'heraldleader': 55678,
#  u'vinalop': 38962,
#  u'chameleons': 15539,
#  u'spiders': 76384,
#  u'bienniale': 54484,
#  u'hanging': 85150,
#  u'woody': 94338,
#  u'suzana': 67596,
#  u'comically': 57840,
#  u'localized': 44264,
#  u'yougoslavia': 7189,
#  u'sprague': 16230,
#  u'gteborg': 82999,
#  u'chanthaburi': 17970,
#  u'igual': 52391,
#  u'bandmeyns': 10335,
#  u'gaa': 89074,
#  u'storiesin': 84637,
#  u'canek': 27791,
#  u'petrak': 44943,
#  u'naturopathic': 42153,
#  u'obscura': 34481,
#  u'bratislava': 86932,
#  u'heroesin': 23118,
#  u'theoryhe': 74282,
#  u'broward': 85834,
#  u'screaming': 85122,
#  u'petras': 70455,
#  u'grueling': 74796,
#  u'vibrational': 53741,
#  u'kangema': 42859,
#  u'dcduring': 33588,
#  u'elgan': 57644,
#  u'wednesday': 93707,
#  u'nielsenfunk': 24347,
#  u'crotch': 13410,
#  u'elgar': 70186,
#  u'598m': 20672,
#  u'perigeepenguin': 51015,
#  u'mcelhinnycolleen': 2399,
#  u'loanstopshop': 6262,
#  u'vintntso': 10023,
#  u'jhey': 18000,
#  u'abdulwahab': 44419,
#  u'270': 86553,
#  u'271': 83371,
#  u'272': 68057,
#  u'273': 67642,
#  u'274': 10850,
#  u'selassie': 83506,
#  u'gorman': 48569,
#  u'277': 77728,
#  u'gwenno': 48174,
#  u'reengineering': 23974,
#  u'finalsst': 1990,
#  u'targa': 21188,
#  u'prosody': 30971,
#  u'musicafter': 81084,
#  u'lmp': 21725,
#  u'usenet': 31807,
#  u'claimsrecently': 36267,
#  u'replaced': 99321,
#  u'olympicsbarnes': 42501,
#  u'backtoback': 94666,
#  u'affiliates': 91682,
#  u'bremweide': 14242,
#  u'perfunctorily': 60003,
#  u'509th': 68794,
#  u'shandling': 4408,
#  u'eventshis': 61187,
#  u'soulin': 47728,
#  u'kids': 97968,
#  u'ansgar': 16200,
#  u'uplifting': 83295,
#  u'votesprior': 56745,
#  u'recordslojo': 36653,
#  u'controversy': 98066,
#  u'fire2': 39075,
#  u'wrelton': 44774,
#  u'kinsley': 3676,
#  u'neurologist': 79685,
#  u'chaoin': 16798,
#  u'topography': 18378,
#  u'jatiyo': 58401,
#  u'projection': 88377,
#  u'jatiya': 76108,
#  u'sterr': 11438,
#  u'realbeanz': 31391,
#  u'battisti': 79088,
#  u'lakembafurolo': 59065,
#  u'stern': 93193,
#  u'battista': 15664,
#  u'pendelton': 43487,
#  u'dnf': 57872,
#  u'testifyby': 40255,
#  u'englandlifsons': 27408,
#  u'dnc': 19003,
#  u'lisan': 38923,
#  u'dni': 79029,
#  u'e0': 13115,
#  u'tcherepnin': 26819,
#  u'ramstein': 36827,
#  u'dns': 72448,
#  u'finucane': 4589,
#  u'releasedrokia': 29895,
#  u'mcclusky': 56308,
#  u'attenboroughii': 4177,
#  u'schoolprior': 5429,
#  u'borstal': 25651,
#  u'populations': 90070,
#  u'gijs': 648,
#  u'gijn': 45759,
#  u'releasehe': 49924,
#  u'injuryplagued': 30591,
#  u'ninetysix': 17467,
#  u'hautzinger': 45388,
#  u'feelinlater': 60381,
#  u'griffinblackjack': 30572,
#  u'intake': 82169,
#  u'morally': 79461,
#  u'carbohydratesdiet': 12417,
#  u'provoste': 40793,
#  u'nakasone': 32891,
#  u'kletka': 24973,
#  u'alkyl': 23103,
#  u'linkshttpblogbestoftexascombestparkeddallasintlfimfestivalreviewhis': 29458,
#  u'generalin': 68508,
#  u'sandies': 45746,
#  u'2253649101066840000000000000000000000': 47233,
#  u'phang': 61967,
#  u'wang': 92842,
#  u'wand': 55620,
#  u'rayos': 58628,
#  u'wank': 17405,
#  u'jidaigeki': 81767,
#  u'disparagement': 52286,
#  u'titanium': 77733,
#  u'want': 98183,
#  u'carew': 6791,
#  u'pinto': 80268,
#  u'bankssmith': 36014,
#  u'olympiadhe': 15200,
#  u'anthologiesshe': 72814,
#  u'tchaikovsky': 89424,
#  u'beyer': 80030,
#  u'carabanchel': 18387,
#  u'travel': 98269,
#  u'fivehe': 17782,
#  u'copious': 35248,
#  u'viennaborn': 10013,
#  u'squaras': 53816,
#  u'dannon': 63654,
#  u'cnnfns': 43687,
#  u'menem': 1121,
#  u'1992in': 73695,
#  u'selfesteem': 73811,
#  u'barbra': 89183,
#  u'midwifing': 23274,
#  u'goober': 10107,
#  u'balado': 6874,
#  u'trollhttan': 57818,
#  u'assimilated': 8039,
#  u'barbri': 30864,
#  u'literaturemorgentaler': 64471,
#  u'sede': 44348,
#  u'leaguesnicknamed': 51727,
#  u'morsesmale': 29345,
#  u'roguelopez': 53315,
#  u'kallios': 2285,
#  u'fckerz': 40327,
#  u'chandos': 62327,
#  u'630000': 54733,
#  u'finalin': 48858,
#  u'ramdas': 49125,
#  u'9898190435154': 59798,
#  u'ontaylor': 17675,
#  u'glenns': 55328,
#  u'orleansin': 66433,
#  u'lambda': 90535,
#  u'speedhoven': 60775,
#  u'rtlhe': 32021,
#  u'suwanee': 35289,
#  u'welcomed': 92685,
#  u'siyum': 16861,
#  u'butcher': 84654,
#  u'concurrency': 24614,
#  u'noddys': 4212,
#  u'8547': 46011,
#  u'ferrante': 80850,
#  u'grzegorz': 78420,
#  u'playhouse': 94884,
#  u'fir': 52661,
#  u'fis': 88265,
#  u'fip': 18689,
#  u'wickedly': 59804,
#  u'fit': 94754,
#  u'reviewingas': 8428,
#  u'berncer': 12752,
#  u'bringing': 97811,
#  u'fix': 85916,
#  u'religionwood': 22190,
#  u'ombudsmanmellor': 50572,
#  u'cyberdemocracy': 6466,
#  u'fia': 86145,
#  u'fig': 69639,
#  u'reentered': 88681,
#  u'fih': 41390,
#  u'fin': 92492,
#  u'fil': 85395,
#  u'uol': 38037,
#  u'zucker': 34115,
#  u'songwriter': 99100,
#  u'rickford': 20320,
#  u'collge': 70709,
#  u'vouchers': 82860,
#  u'schooladmitted': 47737,
#  u'effects': 97720,
#  u'longfordwestmeath': 8992,
#  u'carlotta': 11977,
#  u'turboed': 56039,
#  u'matamoras': 35692,
#  u'cullums': 61389,
#  u'barton': 87776,
#  u'lucero': 57444,
#  u'folha': 21287,
#  u'wooden': 90829,
#  u'chartbyrnes': 54002,
#  u'timeout': 31489,
#  u'ingrid': 88525,
#  u'cowboyin': 50591,
#  u'boyzone': 5875,
#  u'japaneseamerican': 81682,
#  u'szczypiorski': 66798,
#  u'canoeist': 72670,
#  u'onwwwmagic973com': 30302,
#  u'zuid': 7034,
#  u'pavlina': 25049,
#  u'titlefrom': 40651,
#  u'abhimanyu': 56855,
#  u'novices': 56210,
#  u'walchwil': 3673,
#  u'chatterley': 27468,
#  u'golem': 46843,
#  u'apprehendedin': 54905,
#  u'guaira': 47321,
#  u'arava': 11533,
#  u'guaire': 28645,
#  u'undecidable': 57116,
#  u'combinatorial': 30857,
#  u'argentes': 56801,
#  u'adapt': 86137,
#  u'campsouthern': 15687,
#  u'guitarists': 94931,
#  u'9122008': 20841,
#  u'mansonat': 21332,
#  u'jenkinss': 64849,
#  u'abbott': 93015,
#  u'saudiamerican': 65754,
#  u'hirschmore': 62175,
#  u'ooooooone': 64828,
#  u'hagansin': 55733,
#  u'bonelli': 59215,
#  u'oceansstrange': 14873,
#  u'pumpkins': 85187,
#  u'osterhaninge': 50840,
#  u'estimate': 72967,
#  u'gameplay': 31029,
#  u'leela': 53385,
#  u'meachemwhile': 52096,
#  u'prodemocratic': 39142,
#  u'ankalammagudur': 58607,
#  u'habibollah': 22095,
#  u'soodhun': 1447,
#  u'disturbed': 81981,
#  u'bews': 15096,
#  u'santorini': 41270,
#  u'purpose': 96425,
#  u'lazers': 10754,
#  u'yucel': 41184,
#  u'stoneham': 4965,
#  u'227000': 55173,
#  u'stylistics': 66999,
#  u'intimidation': 83554,
#  u'ekwulugoas': 41220,
#  u'masted': 48279,
#  u'oldu': 4883,
#  u'renovated': 88493,
#  u'forrester': 68642,
#  u'lawrelated': 77585,
#  u'highestrated': 23459,
#  u'needed': 97630,
#  u'capsat': 25755,
#  u'master': 99606,
#  u'blueclaws': 4851,
#  u'genesis': 91305,
#  u'berlioz': 75260,
#  u'rewards': 69255,
#  u'enthrall': 19819,
#  u'blackfriars': 57164,
#  u'1during': 15801,
#  u'bonachelabarton': 59744,
#  u'thefrequency': 45986,
#  u'mutilated': 15782,
#  u'ultrasoundprofessor': 30157,
#  u'positively': 74991,
#  u'esapekka': 18715,
#  u'ahmed': 96100,
#  u'drywallrepresentative': 8684,
#  u'196768': 89935,
#  u'duckworth': 53971,
#  u'anniversaries': 4645,
#  u'devaluations': 5050,
#  u'ahmet': 79097,
#  u'exclaimed': 19357,
#  u'schuur': 74135,
#  u'feeling': 94598,
#  u'conominated': 57230,
#  u'schieske': 37505,
#  u'6818': 67287,
#  u'loomans': 41722,
#  u'276': 85540,
#  u'rajaram': 73452,
#  u'whitcomb': 67339,
#  u'parishis': 55115,
#  u'1994tunisia': 59137,
#  u'278': 68291,
#  u'pandemics': 62569,
#  u'mishra': 80191,
#  u'279': 77624,
#  u'harassmenthis': 32673,
#  u'farnham': 82060,
#  u'lesssyncopated': 62395,
#  u'hymel': 10451,
#  u'hymen': 28371,
#  u'pankhida': 31609,
#  u'incshe': 42288,
#  u'kuhnian': 59314,
#  u'shipments': 37549,
#  u'45th': 81136,
#  u'democracyrecently': 4004,
#  u'diminishing': 20887,
#  u'environmentpoetry': 35608,
#  u'cinematic': 90620,
#  u'resonates': 48062,
#  u'meridianboth': 8466,
#  u'midjune': 25940,
#  u'errors': 92282,
#  u'reverence': 75754,
#  u'resonated': 33261,
#  u'baraatu': 49281,
#  u'rocketplane': 1499,
#  u'vicenzain': 4425,
#  u'2008patricio': 3158,
#  u'purges': 30825,
#  u'maja': 35486,
#  u'kiyv': 58204,
#  u'morden': 25787,
#  u'tech': 96717,
#  u'fugitives': 84650,
#  u'keeble': 68509,
#  u'irelandshe': 69904,
#  u'khattar': 17347,
#  u'purged': 76382,
#  u'silber': 20268,
#  u'paladinobonito': 45615,
#  u'franklyn': 50136,
#  u'dickey': 31688,
#  u'londonellis': 23116,
#  u'ijebus': 51256,
#  u'dicken': 2733,
#  u'gebrselassieworku': 12872,
#  u'otello': 83442,
#  u'mid2014however': 59147,
#  u'belgiumaprmay': 27853,
#  u'tempted': 60847,
#  u'havills': 57343,
#  u'topfour': 67129,
#  u'peck': 79606,
#  u'1977bostrom': 61573,
#  u'sessioned': 44951,
#  u'ajayi': 23485,
#  u'lodgein': 18266,
#  u'maltaprofessor': 45839,
#  u'luba': 45622,
#  u'joyon': 5769,
#  u'xlvii': 24683,
#  u'bruneian': 18035,
#  u'plate': 96427,
#  u'plata': 88253,
#  u'sturgess': 37855,
#  u'iatc': 34179,
#  u'replayaberdeen': 50863,
#  u'plath': 3403,
#  u'gehn': 13214,
#  u'firenze': 59378,
#  u'239th': 56961,
#  u'dumontier': 33902,
#  u'2002mcelvaine': 18393,
#  u'panicsville': 24644,
#  u'neurofunction': 51723,
#  u'lds': 95181,
#  u'jaguar': 75539,
#  u'supercoppa': 41791,
#  u'championshipskaltz': 5478,
#  u'nicely': 69419,
#  u'yohimbe': 15091,
#  u'patch': 86212,
#  u'guilln': 10313,
#  u'effectsmusician': 21282,
#  u'viehweg': 38183,
#  u'vhsdvd': 49097,
#  u'rosensafts': 35318,
#  u'programmatic': 76808,
#  u'heirloom': 42183,
#  u'stahre': 43213,
#  u'tyndale': 5730,
#  u'ctvs': 82497,
#  u'7568': 35534,
#  u'pinos': 15780,
#  u'widger': 33648,
#  u'tyndall': 26826,
#  u'pinoy': 34732,
#  u'seventrack': 31883,
#  u'byrnesin': 31226,
#  u'hokoyama': 21424,
#  u'tippit': 13474,
#  u'irr': 36344,
#  u'irs': 85306,
#  u'devilsshirt': 32939,
#  u'irv': 68302,
#  u'lott': 53612,
#  u'xvi': 94602,
#  u'loti': 42418,
#  u'irl': 71154,
#  u'gaventas': 26360,
#  u'srinivas': 19152,
#  u'conductive': 26091,
#  u'subarray': 46770,
#  u'lota': 3240,
#  u'irc': 62062,
#  u'solenoid': 32707,
#  u'discipline': 96454,
#  u'redistricting': 93006,
#  u'extend': 93765,
#  u'nature': 98818,
#  u'fruits': 83313,
#  u'publishingglasss': 21986,
#  u'parramatta': 87888,
#  u'meridional': 4999,
#  u'toyotaunited': 49373,
#  u'chine': 2093,
#  u'miyake': 1734,
#  u'worldchampion': 56418,
#  u'teitel': 46254,
#  u'isringhausen': 65428,
#  u'lookin': 46461,
#  u'almirqab': 22824,
#  u'mormonsorenson': 15043,
#  u'miyaku': 20151,
#  u'lishs': 66806,
#  u'libyan': 75781,
#  u'crosswordshe': 46124,
#  u'physiotherapist': 82981,
#  u'52according': 1736,
#  u'borrussia': 27257,
#  u'gopher': 11481,
#  u'salvagedused': 52452,
#  u'lankain': 15873,
#  u'kiskesomerville': 32319,
#  u'athan': 16704,
#  u'popebesides': 58641,
#  u'codirect': 61459,
#  u'smackdown': 78505,
#  u'szetela': 50743,
#  u'lanett': 47595,
#  u'fra': 83561,
#  u'angel': 96937,
#  u'thensoviet': 32680,
#  u'muck': 82770,
#  u'contemporariesmusicians': 21605,
#  u'much': 99757,
#  u'chink': 28968,
#  u'fru': 32643,
#  u'akademiet': 12461,
#  u'fry': 84847,
#  u'distinctio': 66960,
#  u'spir': 11379,
#  u'hepp': 74366,
#  u'schmidton': 58525,
#  u'spit': 2757,
#  u'yzme': 44633,
#  u'jeon': 18267,
#  u'ibjjf': 68426,
#  u'kalipay': 53789,
#  u'2002smiths': 56222,
#  u'spie': 77243,
#  u'spin': 95218,
#  u'wildcat': 16950,
#  u'utopiales': 19880,
#  u'mcelhinnyjack': 13226,
#  u'professionally': 98214,
#  u'sreten': 61916,
#  u'broadstairs': 18734,
#  u'slaveholders': 3911,
#  u'fortyyear': 13908,
#  u'koha': 21932,
#  u'canoeing': 81388,
#  u'kohn': 49934,
#  u'ceiops': 6115,
#  u'kohl': 26851,
#  u'kohs': 52069,
#  u'1988following': 9760,
#  u'waddell': 26355,
#  u'athleticborn': 24241,
#  u'hyperdrive': 7174,
#  u'5050': 80724,
#  u'hone': 79826,
#  u'memorial': 98834,
#  u'honf': 6626,
#  u'brigadetirawis': 32336,
#  u'portobello': 4308,
#  u'remand': 45397,
#  u'umarovuntil': 30538,
#  u'democracies': 69934,
#  u'columnistacua': 38481,
#  u'insilixia': 13507,
#  u'hons': 92359,
#  u'kidd': 90681,
#  u'memorias': 13028,
#  u'isupubblicazioni': 24338,
#  u'lifechristian': 63174,
#  u'chauvinistic': 60973,
#  u'georgics': 14705,
#  u'shudhi': 65222,
#  u'signedmaikoris': 16854,
#  u'selfmanagement': 13467,
#  u'charon': 41052,
#  u'menwan': 46991,
#  u'mentors': 84401,
#  u'menwar': 60771,
#  u'academic': 99571,
#  u'stillness': 49463,
#  u'academia': 95443,
#  u'academie': 68653,
#  u'evansvillevanderburgh': 28182,
#  u'bellot': 21882,
#  u'aldhousegreens': 19048,
#  u'bmgkool': 20070,
#  u'willesden': 75496,
#  u'rightslater': 8362,
#  u'appropriately': 88745,
#  u'shellover': 55181,
#  u'dtat': 81008,
#  u'involvedhe': 59370,
#  u'lasse': 75886,
#  u'subtlehis': 53383,
#  u'tchamantch': 30751,
#  u'madeiraproduced': 249,
#  u'wagnerhamanns': 58176,
#  u'haj': 13798,
#  u'hal': 93304,
#  u'ham': 92628,
#  u'han': 91421,
#  u'hao': 71513,
#  u'2012carolyn': 18453,
#  u'hab': 34805,
#  u'hac': 10448,
#  u'festpiel': 5841,
#  u'pastchairman': 24475,
#  u'watercolour': 72148,
#  u'competitively': 89020,
#  u'gtersloh': 23680,
#  u'hay': 91332,
#  u'mcnamara': 83873,
#  u'ftcd': 28924,
#  u'projectsengel': 32694,
#  u'gamesladson': 36716,
#  u'bemsha': 45469,
#  u'haq': 59592,
#  u'har': 45201,
#  u'has': 100262,
#  u'hat': 93727,
#  u'jockeybased': 11574,
#  u'768819': 63493,
#  u'dokka': 28893,
#  u'municipal': 98588,
#  u'allnba': 76859,
#  u'elders': 87162,
#  u'gligori': 42127,
#  u'politicsas': 46463,
#  u'unequivocally': 51431,
#  u'pissmops': 33694,
#  u'dagar': 75321,
#  u'dokku': 26630,
#  u'gllivare': 61875,
#  u'clevedon': 71573,
#  u'cyberpunkbased': 13283,
#  u'satriani': 80585,
#  u'nonconsecutive': 59805,
#  u'victorvictoria': 78155,
#  u'independencefollowing': 40984,
#  u'semi': 91848,
#  u'professorbartlett': 4239,
#  u'purati': 20238,
#  u'lacroix': 73227,
#  u'highwaypetyarre': 10682,
#  u'yoweri': 65353,
#  u'crowd': 96341,
#  u'encampmentin': 59924,
#  u'czech': 97201,
#  u'fallingout': 5559,
#  u'karanikis': 4333,
#  u'coachfrom': 12215,
#  u'crown': 97917,
#  u'zlatko': 70415,
#  u'giedr': 65081,
#  u'altoona': 45436,
#  u'vangelo': 32427,
#  u'dailyhe': 22289,
#  u'irgensjensen': 15769,
#  u'commonwealthstate': 16298,
#  u'kidu': 30206,
#  u'kapuskasing': 649,
#  u'botton': 46712,
#  u'bottom': 94643,
#  u'maalaisille': 64068,
#  u'golfertshabalala': 23196,
#  u'wirklichkeit': 1218,
#  u'enhancementsandberg': 48927,
#  u'troopsfor': 61463,
#  u'vietcong': 18648,
#  u'seekersthe': 65215,
#  u'siepashe': 62354,
#  u'petersons': 24321,
#  u'buckleys': 75194,
#  u'andalas': 23517,
#  u'brigades': 84426,
#  u'starring': 99140,
#  u'dna': 93973,
#  u'priggenross': 39852,
#  u'boulavarde': 28155,
#  u'releasekorey': 18042,
#  u'fiveway': 12256,
#  u'myfontscommarshs': 18591,
#  u'bencher': 83196,
#  u'benches': 86131,
#  u'cahoone': 56209,
#  u'dcarea': 47129,
#  u'officeholders': 77811,
#  u'benched': 25418,
#  u'heineheine': 499,
#  u'museummilwaukee': 2831,
#  u'cahoons': 2983,
#  u'electionborn': 46517,
#  u'wdzydze': 62306,
#  u'dyson': 82621,
#  u'honeymoon': 49238,
#  u'nongovernmental': 93524,
#  u'marshals': 11337,
#  u'university3': 59745,
#  u'shoots': 85482,
#  u'ashkenazic': 5577,
#  u'breno': 51366,
#  u'despised': 27499,
#  u'fabric': 79589,
#  u'africanborn': 83445,
#  u'raped': 87818,
#  u'fossellamr': 16166,
#  u'grasping': 23838,
#  u'manageroperation': 33102,
#  u'repassando': 21666,
#  u'allsoutheastern': 32280,
#  u'alexandrian': 10609,
#  u'43000': 24085,
#  u'perfumes': 81407,
#  u'coleone': 22214,
#  u'californiakoblins': 9030,
#  u'thorgersen': 65981,
#  u'germanirish': 24102,
#  u'aogan': 36480,
#  u'rawers': 59572,
#  u'universitys': 98480,
#  u'lydiard': 21575,
#  u'congratulations': 23428,
#  u'flawlessly': 76317,
#  u'recolectores': 6142,
#  u'rippling': 8215,
#  u'sermons': 86456,
#  u'americabeauchamp': 36559,
#  u'morning': 98958,
#  u'sept2013on': 47941,
#  u'bazz': 60960,
#  u'nicest': 40659,
#  u'moderna': 59279,
#  u'disgrace': 76421,
#  u'moderne': 85879,
#  u'barrymore': 73698,
#  u'bloedow': 5148,
#  u'mirror': 95455,
#  u'moderno': 72849,
#  u'matmos': 26469,
#  u'samilidis': 18487,
#  u'altona': 77017,
#  u'dannilynn': 18269,
#  u'ninthranked': 49703,
#  u'yearssansom': 37654,
#  u'cazzetta': 2182,
#  u'crowns': 80789,
#  u'pasadena': 94123,
#  u'preobrajenska': 29554,
#  u'nirina': 45391,
#  u'crowne': 75180,
#  u'loret': 55340,
#  u'palms': 89218,
#  u'investigationswhen': 46540,
#  u'1990the': 67677,
#  u'16113': 17672,
#  u'safetykleen': 31600,
#  u'yahoo': 91852,
#  u'palme': 69324,
#  u'youmans': 8933,
#  u'moresby': 50012,
#  u'palma': 83578,
#  u'kitson': 58296,
#  u'brothersinlaw': 49825,
#  u'danske': 11928,
#  u'friedhelm': 16557,
#  u'edos': 11221,
#  u'explosions': 87027,
#  u'loren': 77764,
#  u'wonwbc': 57919,
#  u'qmjhl': 84975,
#  u'shootout': 91709,
#  u'borle': 53126,
#  u'mononym': 35672,
#  u'povey': 36196,
#  u'mswati': 60649,
#  u'baradwaj': 62186,
#  u'erzulie': 36432,
#  u'expeditionary': 82405,
#  u'childs': 93480,
#  u'delunas': 12831,
#  u'corps': 97993,
#  u'colognegermany2001': 26822,
#  u'egba': 71525,
#  u'pastner': 31667,
#  u'egypts': 87321,
#  u'childe': 4991,
#  u'presidentdirector': 25933,
#  u'gumbo': 33788,
#  u'brainchild': 1387,
#  u'chair': 99687,
#  u'chait': 49675,
#  u'macht': 9821,
#  u'larc': 71088,
#  u'descentthroughout': 8647,
#  u'kfis': 55097,
#  u'freelance': 98503,
#  u'lara': 89953,
#  u'8869': 15113,
#  u'mache': 46122,
#  u'multiskilling': 10441,
#  u'30save': 14398,
#  u'studyfirst': 34795,
#  u'binderamgen': 5482,
#  u'jardines': 1438,
#  u'zucco': 3450,
#  u'tenacious': 78864,
#  u'hezrfen': 39482,
#  u'paychecks': 25958,
#  u'jerk': 20503,
#  u'jere': 62582,
#  u'prancer': 47698,
#  u'biopharmaceuticals': 2025,
#  u'rivalryin': 48678,
#  u'strawblocks': 23123,
#  u'embark': 80156,
#  u'ingenieros': 46519,
#  u'therehis': 37236,
#  u'crackdowns': 8612,
#  u'hunterdon': 30647,
#  u'exact': 92257,
#  u'inglis': 4783,
#  u'minute': 97102,
#  u'advocacyhe': 14391,
#  u'mawawala': 6015,
#  u'iithe': 74507,
#  u'whackedout': 66197,
#  u'nedjeljna': 31766,
#  u'illustrators': 90042,
#  u'instituteafter': 33718,
#  u'mineko': 70549,
#  u'organon': 41849,
#  u'nadwah': 33810,
#  u'versatility': 93530,
#  u'unmit': 3396,
#  u'hindered': 64884,
#  u'200507': 64620,
#  u'columnhe': 43070,
#  u'gyeonggi': 34405,
#  u'ogles': 14959,
#  u'unmil': 51675,
#  u'heavyweight': 93303,
#  u'unmih': 34916,
#  u'trisha': 81131,
#  u'unmik': 21555,
#  u'securityin': 42092,
#  u'poneke': 36387,
#  u'helmin': 40431,
#  u'bagging': 70651,
#  u'malattia': 30459,
#  u'corazon': 69242,
#  u'massironi': 16122,
#  u'antwerp': 92835,
#  u'burch': 45859,
#  u'lucasfilmapproved': 5668,
#  u'partymoehle': 1791,
#  u'ufa': 50620,
#  u'geography': 95514,
#  u'celebrates': 90389,
#  u'trinidadian': 75298,
#  u'drafted': 99166,
#  u'paribas': 68975,
#  u'oldies': 87795,
#  u'climbs': 28492,
#  u'honour': 97745,
#  u'universityshu': 8949,
#  u'vanderbilt': 93273,
#  u'bredbennerturning': 44679,
#  u'bowmans': 58593,
#  u'306': 67617,
#  u'earthhe': 4945,
#  u'address': 97390,
#  u'dwindling': 44382,
#  u'awardheenan': 15673,
#  u'benson': 93652,
#  u'flodin': 1496,
#  u'nonfull': 62739,
#  u'rosterlater': 15149,
#  u'lengle': 56357,
#  u'impacted': 85460,
#  u'cette': 13585,
#  u'terminator2004': 30442,
#  u'queue': 78841,
#  u'panarab': 39839,
#  u'darmo': 16507,
#  u'storps': 59853,
#  u'fichandlers': 30169,
#  u'raise': 97883,
#  u'ellensburg': 46324,
#  u'houseman': 80602,
#  u'proportion': 84947,
#  u'sistemas': 8373,
#  u'womenswear': 70567,
#  u'cadernos': 14062,
#  u'albumas': 1013,
#  u'darnell': 85981,
#  u'opposes': 85816,
#  u'handbags': 14906,
#  u'pints': 44238,
#  u'intermediary': 70326,
#  u'vigour': 26918,
#  u'selfpublished': 89221,
#  u'institutes2': 28194,
#  u'israelstern': 2308,
#  u'pavilions': 51170,
#  u'chelle': 64802,
#  u'weisgalls': 28434,
#  u'magazinesoutside': 26329,
#  u'singersongwriterperformance': 48451,
#  u'rehovot': 47428,
#  u'concertgebouw': 90638,
#  u'wvu': 31551,
#  u'violationduring': 5614,
#  u'consoles': 10271,
#  u'goods': 94134,
#  u'calapp4th': 66109,
#  u'vonneumann': 3317,
#  u'bharati': 79793,
#  u'198995': 22041,
#  u'198992': 10835,
#  u'198993': 3757,
#  u'198990': 90264,
#  u'198991': 49316,
#  u'symposiumskennedy': 63044,
#  u'rebounding': 90295,
#  u'pointsterlich': 6848,
#  u'neosoul': 37614,
#  u'gregoire': 69142,
#  u'rutherford': 89972,
#  u'ebeid': 51599,
#  u'rushkoff': 47504,
#  u'hellenic': 88590,
#  u'following': 100133,
#  u'vfree': 38382,
#  u'policypaul': 32024,
#  u'zlem': 41431,
#  u'bisu': 33638,
#  u'tarvisio': 63707,
#  u'1987hon': 8461,
#  u'lodestone': 36528,
#  u'2011before': 54934,
#  u'bundesbank': 11657,
#  u'aksys': 22091,
#  u'sinoarabic': 56680,
#  u'litre': 71914,
#  u'dosir': 2031,
#  u'bibliographical': 40923,
#  u'londonpeterbroughengland2006': 65487,
#  u'litro': 60862,
#  u'rheinruhrripper': 62093,
#  u'ounce': 16560,
#  u'cecam': 40545,
#  u'heritagehis': 50413,
#  u'cecab': 35132,
#  u'compiegne': 30136,
#  u'radames': 73253,
#  u'yalom': 66229,
#  u'appointedalready': 38865,
#  u'epidemiologic': 41007,
#  u'sour': 84931,
#  u'falluja': 49771,
#  u'kodly': 27747,
#  u'convincingly': 67613,
#  u'fueled': 77993,
#  u'sociolinguistics': 86595,
#  u'tourearth': 46730,
#  u'ventureprevious': 43350,
#  u'harmon': 52253,
#  u'ctohe': 44258,
#  u'heliotrope': 36048,
#  u'jonnie': 20701,
#  u'0394537173the': 50493,
#  u'antiyeltsin': 31935,
#  u'warring': 4349,
#  u'okul': 27979,
#  u'inhabiting': 74222,
#  u'trialled': 70204,
#  u'kjrh': 11791,
#  u'forebears': 55721,
#  u'skirmish': 999,
#  u'cycleduring': 67119,
#  u'jurek': 18951,
#  u'impactful': 19148,
#  u'tilney': 76947,
#  u'shirked': 27061,
#  u'piedi': 32906,
#  u'16year': 9104,
#  u'semifiction': 36794,
#  u'1when': 51423,
#  u'oklahoma7': 1756,
#  u'kavalek': 63771,
#  u'jimmy': 98496,
#  u'composerarranger': 71017,
#  u'honours': 98626,
#  u'anticircumvention': 12455,
#  u'tula': 76560,
#  u'brudenellbruce': 32806,
#  u'1988torstensen': 43732,
#  u'andrewsmost': 66405,
#  u'montaano': 19594,
#  u'jia': 43919,
#  u'tuli': 75259,
#  u'greeks': 74676,
#  u'jim': 99195,
#  u'jij': 16956,
#  u'tull': 71910,
#  u'centerhe': 61643,
#  u'gazetaru': 61313,
#  u'jiu': 44040,
#  u'jir': 14972,
#  u'preseasonfrom': 23744,
#  u'dimanno': 44484,
#  u'apron': 58101,
#  u'belowa': 50300,
#  u'aprof': 49305,
#  u'metairie': 61742,
#  u'manwel': 62295,
#  u'rigbysince': 25061,
#  u'belows': 31929,
#  u'coorparoos': 5195,
#  u'sutyagin': 15053,
#  u'threeandahalf': 6875,
#  u'2009langan': 42415,
#  u'deady': 61796,
#  u'hickory': 85017,
#  u'ladysmith': 48728,
#  u'didi': 10822,
#  u'wolfsonianfiu': 67153,
#  u'apia': 76130,
#  u'genizah': 18546,
#  u'instability': 79463,
#  u'quarter': 96800,
#  u'didy': 34558,
#  ...}

# %%
map_index_to_word = pd.DataFrame(map_index_to_word.items(), columns=['word', 'index'])

# %%
map_index_to_word
# Out:
#                        word  index
# 0          sundayswadsworth  37318
# 1                  verplank  46431
# 2                   damfunk  23253
# 3                     anyer  62437
# 4                     sonja  37922
# 5                   degussa  33295
# 6              heraldleader  55678
# 7                   vinalop  38962
# 8                chameleons  15539
# 9                   spiders  76384
# 10                bienniale  54484
# 11                  hanging  85150
# 12                    woody  94338
# 13                   suzana  67596
# 14                comically  57840
# 15                localized  44264
# 16              yougoslavia   7189
# 17                  sprague  16230
# 18                  gteborg  82999
# 19              chanthaburi  17970
# 20                    igual  52391
# 21                bandmeyns  10335
# 22                      gaa  89074
# 23                storiesin  84637
# 24                    canek  27791
# 25                   petrak  44943
# 26             naturopathic  42153
# 27                  obscura  34481
# 28               bratislava  86932
# 29                 heroesin  23118
# ...                     ...    ...
# 100252                 sich  48987
# 100253               branch  98189
# 100254             tredegar   5789
# 100255              kerouac  65505
# 100256              chatted  66828
# 100257             roleplay  33349
# 100258               branca  41846
# 100259                lance  91794
# 100260              wendeng  51640
# 100261              stachel  11879
# 100262             anoushka   5175
# 100263             contends  88953
# 100264  examinationspaulker  30611
# 100265                lancs  30247
# 100266              boyband  40479
# 100267         finkenzeller  37573
# 100268            catalogin  65710
# 100269                  18b  46420
# 100270              1941his  55226
# 100271                tieon   9258
# 100272             dunstall  56365
# 100273                 35mm  84579
# 100274                 vous  68120
# 100275                sptar  25502
# 100276                goole  75096
# 100277                agios  11752
# 100278                 luqa  28927
# 100279              expands  79306
# 100280   championshiphaving  57279
# 100281                corey  87290
#
# [100282 rows x 2 columns]

# %%
tf_idf = normalize(tf_idf)

# %%
def diag(array):
    n = len(array)
    return spdiags(array, 0, n, n)

def logpdf_diagonal_gaussian(x, mean, cov):
    '''
    Compute logpdf of a multivariate Gaussian distribution with diagonal covariance at a given point x.
    A multivariate Gaussian distribution with a diagonal covariance is equivalent
    to a collection of independent Gaussian random variables.

    x should be a sparse matrix. The logpdf will be computed for each row of x.
    mean and cov should be given as 1D numpy arrays
    mean[i] : mean of i-th variable
    cov[i] : variance of i-th variable'''

    n = x.shape[0]
    dim = x.shape[1]
    assert(dim == len(mean) and dim == len(cov))

    # multiply each i-th column of x by (1/(2*sigma_i)), where sigma_i is sqrt of variance of i-th variable.
    scaled_x = x.dot( diag(1./(2*np.sqrt(cov))) )
    # multiply each i-th entry of mean by (1/(2*sigma_i))
    scaled_mean = mean/(2*np.sqrt(cov))

    # sum of pairwise squared Eulidean distances gives SUM[(x_i - mean_i)^2/(2*sigma_i^2)]
    return -np.sum(np.log(np.sqrt(2*np.pi*cov))) - pairwise_distances(scaled_x, [scaled_mean], 'euclidean').flatten()**2

# %%
def log_sum_exp(x, axis):
    '''Compute the log of a sum of exponentials'''
    x_max = np.max(x, axis=axis)
    if axis == 1:
        return x_max + np.log( np.sum(np.exp(x-x_max[:,np.newaxis]), axis=1) )
    else:
        return x_max + np.log( np.sum(np.exp(x-x_max), axis=0) )

def EM_for_high_dimension(data, means, covs, weights, cov_smoothing=1e-5, maxiter=int(1e3), thresh=1e-4, verbose=False):
    # cov_smoothing: specifies the default variance assigned to absent features in a cluster.
    #                If we were to assign zero variances to absent features, we would be overconfient,
    #                as we hastily conclude that those featurese would NEVER appear in the cluster.
    #                We'd like to leave a little bit of possibility for absent features to show up later.
    n = data.shape[0]
    dim = data.shape[1]
    mu = deepcopy(means)
    Sigma = deepcopy(covs)
    K = len(mu)
    weights = np.array(weights)

    ll = None
    ll_trace = []

    for i in range(maxiter):
        # E-step: compute responsibilities
        logresp = np.zeros((n,K))
        for k in xrange(K):
            logresp[:,k] = np.log(weights[k]) + logpdf_diagonal_gaussian(data, mu[k], Sigma[k])
        ll_new = np.sum(log_sum_exp(logresp, axis=1))
        if verbose:
            print(ll_new)
        logresp -= np.vstack(log_sum_exp(logresp, axis=1))
        resp = np.exp(logresp)
        counts = np.sum(resp, axis=0)

        # M-step: update weights, means, covariances
        weights = counts / np.sum(counts)
        for k in range(K):
            mu[k] = (diag(resp[:,k]).dot(data)).sum(axis=0)/counts[k]
            mu[k] = mu[k].A1

            Sigma[k] = diag(resp[:,k]).dot( data.multiply(data)-2*data.dot(diag(mu[k])) ).sum(axis=0) \
                       + (mu[k]**2)*counts[k]
            Sigma[k] = Sigma[k].A1 / counts[k] + cov_smoothing*np.ones(dim)

        # check for convergence in log-likelihood
        ll_trace.append(ll_new)
        if ll is not None and (ll_new-ll) < thresh and ll_new > -np.inf:
            ll = ll_new
            break
        else:
            ll = ll_new

    out = {'weights':weights,'means':mu,'covs':Sigma,'loglik':ll_trace,'resp':resp}

    return out

# %%
from sklearn.cluster import KMeans

np.random.seed(5)
num_clusters = 25

# Use scikit-learn's k-means to simplify workflow
kmeans_model = KMeans(n_clusters=num_clusters, n_init=5, max_iter=400, random_state=1, n_jobs=-1)
kmeans_model.fit(tf_idf)
centroids, cluster_assignment = kmeans_model.cluster_centers_, kmeans_model.labels_

means = [centroid for centroid in centroids]

# %%
means
# Out:
# [array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.01954039e-04,   1.04447276e-04,   9.87192763e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.98056588e-04,   1.43796792e-04,   8.95769954e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.16092642e-04,   1.45670542e-04,   8.38163507e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.13464464e-04,   1.01278436e-04,   9.25652957e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.94720759e-04,   8.29483688e-05,   1.16312561e-04]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.20138346e-04,   9.94621358e-05,   9.23794738e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.16754523e-04,   1.27676596e-04,   8.65020280e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.69276781e-04,   8.25281851e-05,   9.35820869e-05]),
#  array([  1.74113128e-04,   0.00000000e+00,   0.00000000e+00, ...,
#           1.71902936e-04,   1.14429476e-04,   7.67297965e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.76690425e-04,   1.31721796e-04,   8.80419609e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.44240787e-04,   8.50124538e-05,   9.56486387e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.00305928e-04,   1.25656165e-04,   9.29831196e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.83282926e-04,   1.47220111e-04,   7.89853219e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.02081480e-04,   1.47602955e-04,   9.59351504e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.20265206e-04,   1.38994715e-04,   8.96768858e-05]),
#  array([  0.00000000e+00,   2.32765703e-04,   0.00000000e+00, ...,
#           1.63744849e-04,   1.34271391e-04,   7.60632266e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.49105124e-04,   8.32739625e-05,   9.60564428e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.72682496e-04,   1.35875062e-04,   7.99896524e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.88179111e-04,   1.04754698e-04,   9.30664401e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.52702754e-04,   8.61209384e-05,   8.49277634e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.92064312e-04,   1.51261740e-04,   9.92517200e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   6.01372645e-04, ...,
#           2.02623936e-04,   1.11192125e-04,   9.19916839e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.52539829e-04,   9.91611421e-05,   9.98666161e-05]),
#  array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.00512550e-04,   1.49560114e-04,   8.74332729e-05]),
#  array([ 0.        ,  0.        ,  0.        , ...,  0.00025528,
#          0.00010363,  0.00010478])]

# %%
num_docs = tf_idf.shape[0]
weights = []
for i in xrange(num_clusters):
    # Compute the number of data points assigned to cluster i:
    num_assigned = len(cluster_assignment[cluster_assignment == i])
    w = float(num_assigned) / num_docs
    weights.append(w)

# %%
weights
# Out:
# [0.0512,
#  0.0256,
#  0.0318,
#  0.0132,
#  0.01,
#  0.0212,
#  0.0782,
#  0.0282,
#  0.1676,
#  0.017,
#  0.0196,
#  0.0526,
#  0.0266,
#  0.047,
#  0.048,
#  0.083,
#  0.0168,
#  0.0256,
#  0.0166,
#  0.0508,
#  0.0182,
#  0.0338,
#  0.014,
#  0.0688,
#  0.0346]

# %%
sum(weights)
# Out:
# 1.0

# %%
covs = []
for i in xrange(num_clusters):
    member_rows = tf_idf[cluster_assignment==i]
    cov = (member_rows.multiply(member_rows) - 2*member_rows.dot(diag(means[i]))).sum(axis=0).A1 / member_rows.shape[0] \
          + means[i]**2
    cov[cov < 1e-8] = 1e-8
    covs.append(cov)

# %%
out = EM_for_high_dimension(tf_idf, means, covs, weights, cov_smoothing=1e-10)
print out['loglik']
# Out:
# [3855847476.6997027, 4844053202.4563665, 4844053202.4563665]

# %%
# Fill in the blanks
def visualize_EM_clusters(tf_idf, means, covs, map_index_to_word):
    print('')
    print('==========================================================')

    num_clusters = len(means)
    for c in xrange(num_clusters):
        print('Cluster {0:d}: Largest mean parameters in cluster '.format(c))
        print('\n{0: <12}{1: <12}{2: <12}'.format('Word', 'Mean', 'Variance'))
        
        # The k'th element of sorted_word_ids should be the index of the word 
        # that has the k'th-largest value in the cluster mean. Hint: Use np.argsort().
        sorted_word_ids = np.argsort(means[c])[::-1]

        for i in sorted_word_ids[:5]:
            word = map_index_to_word[map_index_to_word['index'] == i]['word']
            print '{0: <12}{1:<10.2e}{2:10.2e}'.format(word, 
                                                       means[c][i],
                                                       covs[c][i])
        print '\n=====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]===='

# %%
visualize_EM_clusters(tf_idf, out['means'], out['covs'], map_index_to_word)
# Out:
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 35365    minister
# Name: word, dtype: object7.57e-02    7.42e-03
# 9571    election
# Name: word, dtype: object5.89e-02    3.21e-03
# 55669    party
# Name: word, dtype: object5.89e-02    2.61e-03
# 12737    liberal
# Name: word, dtype: object2.93e-02    4.55e-03
# 78889    elected
# Name: word, dtype: object2.91e-02    8.95e-04
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 1: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 82263    film
# Name: word, dtype: object1.76e-01    6.07e-03
# 30008    films
# Name: word, dtype: object5.50e-02    2.97e-03
# 90293    festival
# Name: word, dtype: object4.66e-02    3.60e-03
# 74657    feature
# Name: word, dtype: object3.69e-02    1.81e-03
# 45729    directed
# Name: word, dtype: object3.39e-02    2.22e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 2: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 99041    art
# Name: word, dtype: object1.26e-01    6.83e-03
# 93543    museum
# Name: word, dtype: object5.62e-02    7.27e-03
# 55473    gallery
# Name: word, dtype: object3.65e-02    3.40e-03
# 38377    artist
# Name: word, dtype: object3.61e-02    1.44e-03
# 23104    design
# Name: word, dtype: object3.20e-02    4.59e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 3: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 24890    basketball
# Name: word, dtype: object1.86e-01    7.78e-03
# 98665    nba
# Name: word, dtype: object1.01e-01    1.22e-02
# 88378    points
# Name: word, dtype: object6.25e-02    5.92e-03
# 84674    coach
# Name: word, dtype: object5.57e-02    5.91e-03
# 62861    team
# Name: word, dtype: object4.68e-02    1.30e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 4: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 63206    hockey
# Name: word, dtype: object2.45e-01    1.64e-02
# 9243    nhl
# Name: word, dtype: object1.56e-01    1.64e-02
# 22075    ice
# Name: word, dtype: object6.40e-02    2.97e-03
# 47777    season
# Name: word, dtype: object5.05e-02    2.52e-03
# 30563    league
# Name: word, dtype: object4.31e-02    1.53e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 5: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 61450    republican
# Name: word, dtype: object7.93e-02    5.20e-03
# 26816    senate
# Name: word, dtype: object5.41e-02    6.28e-03
# 72895    house
# Name: word, dtype: object4.64e-02    2.41e-03
# 78624    district
# Name: word, dtype: object4.60e-02    2.37e-03
# 37414    democratic
# Name: word, dtype: object4.46e-02    3.02e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 6: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 17954    she
# Name: word, dtype: object1.60e-01    4.65e-03
# 26108    her
# Name: word, dtype: object1.00e-01    3.14e-03
# 42120    miss
# Name: word, dtype: object2.22e-02    7.76e-03
# 49188    women
# Name: word, dtype: object1.43e-02    1.36e-03
# 86159    womens
# Name: word, dtype: object1.21e-02    1.46e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 7: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 3119    championships
# Name: word, dtype: object7.78e-02    5.17e-03
# 69795    m
# Name: word, dtype: object4.70e-02    7.58e-03
# 43851    olympics
# Name: word, dtype: object4.69e-02    2.59e-03
# 91133    medal
# Name: word, dtype: object4.28e-02    2.44e-03
# 17954    she
# Name: word, dtype: object4.18e-02    5.99e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 8: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 49788    book
# Name: word, dtype: object1.45e-02    9.38e-04
# 45083    published
# Name: word, dtype: object1.23e-02    6.16e-04
# 91574    that
# Name: word, dtype: object1.10e-02    1.73e-04
# 10530    novel
# Name: word, dtype: object1.07e-02    1.43e-03
# 68168    he
# Name: word, dtype: object1.04e-02    6.05e-05
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 9: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 17954    she
# Name: word, dtype: object1.37e-01    4.25e-03
# 26108    her
# Name: word, dtype: object8.99e-02    2.74e-03
# 13971    actress
# Name: word, dtype: object7.65e-02    4.29e-03
# 82263    film
# Name: word, dtype: object5.98e-02    3.44e-03
# 96025    drama
# Name: word, dtype: object5.03e-02    6.40e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 10: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 10706    soccer
# Name: word, dtype: object1.15e-01    2.86e-02
# 43758    chess
# Name: word, dtype: object4.52e-02    1.66e-02
# 62861    team
# Name: word, dtype: object4.13e-02    2.15e-03
# 84674    coach
# Name: word, dtype: object3.09e-02    4.45e-03
# 30563    league
# Name: word, dtype: object3.07e-02    2.01e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 11: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 31012    president
# Name: word, dtype: object2.52e-02    1.29e-03
# 23416    chairman
# Name: word, dtype: object2.44e-02    1.97e-03
# 80967    committee
# Name: word, dtype: object2.34e-02    2.38e-03
# 82160    served
# Name: word, dtype: object2.24e-02    6.99e-04
# 96787    executive
# Name: word, dtype: object2.15e-02    1.23e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 12: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 49935    music
# Name: word, dtype: object7.26e-02    3.48e-03
# 10135    jazz
# Name: word, dtype: object6.07e-02    1.14e-02
# 3177    hong
# Name: word, dtype: object3.78e-02    9.92e-03
# 63008    kong
# Name: word, dtype: object3.50e-02    8.64e-03
# 85453    chinese
# Name: word, dtype: object3.12e-02    5.33e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 13: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 5424    university
# Name: word, dtype: object3.47e-02    8.89e-04
# 84644    history
# Name: word, dtype: object3.38e-02    2.81e-03
# 70803    philosophy
# Name: word, dtype: object2.86e-02    5.35e-03
# 12363    professor
# Name: word, dtype: object2.74e-02    1.08e-03
# 79811    studies
# Name: word, dtype: object2.41e-02    1.95e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 14: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 94850    theatre
# Name: word, dtype: object4.93e-02    6.17e-03
# 62782    actor
# Name: word, dtype: object3.56e-02    2.91e-03
# 28839    television
# Name: word, dtype: object3.21e-02    1.67e-03
# 82263    film
# Name: word, dtype: object2.93e-02    1.16e-03
# 2399    comedy
# Name: word, dtype: object2.86e-02    3.91e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 15: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 28764    album
# Name: word, dtype: object6.76e-02    4.78e-03
# 77923    band
# Name: word, dtype: object5.35e-02    4.21e-03
# 49935    music
# Name: word, dtype: object4.18e-02    1.96e-03
# 91242    released
# Name: word, dtype: object3.13e-02    1.11e-03
# 90519    song
# Name: word, dtype: object2.50e-02    1.81e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 16: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 7178    tour
# Name: word, dtype: object1.14e-01    1.92e-02
# 83391    pga
# Name: word, dtype: object1.08e-01    2.65e-02
# 85511    racing
# Name: word, dtype: object8.45e-02    8.26e-03
# 98586    championship
# Name: word, dtype: object6.27e-02    4.54e-03
# 38225    formula
# Name: word, dtype: object6.06e-02    1.31e-02
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 17: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 59421    news
# Name: word, dtype: object5.76e-02    8.06e-03
# 84292    radio
# Name: word, dtype: object5.18e-02    4.62e-03
# 32087    show
# Name: word, dtype: object3.75e-02    2.56e-03
# 99993    bbc
# Name: word, dtype: object3.63e-02    7.41e-03
# 80136    chef
# Name: word, dtype: object3.27e-02    1.18e-02
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 18: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 9679    football
# Name: word, dtype: object1.11e-01    5.60e-03
# 38050    yards
# Name: word, dtype: object7.37e-02    1.72e-02
# 24065    nfl
# Name: word, dtype: object6.98e-02    9.15e-03
# 84674    coach
# Name: word, dtype: object6.74e-02    7.85e-03
# 6336    quarterback
# Name: word, dtype: object4.02e-02    7.16e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 19: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 30563    league
# Name: word, dtype: object5.21e-02    3.13e-03
# 91361    club
# Name: word, dtype: object5.04e-02    2.64e-03
# 47777    season
# Name: word, dtype: object4.77e-02    2.30e-03
# 69500    rugby
# Name: word, dtype: object4.35e-02    8.18e-03
# 57957    cup
# Name: word, dtype: object4.22e-02    2.46e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 20: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 87468    orchestra
# Name: word, dtype: object1.31e-01    1.06e-02
# 49935    music
# Name: word, dtype: object1.23e-01    6.15e-03
# 74611    symphony
# Name: word, dtype: object8.70e-02    1.08e-02
# 47567    conductor
# Name: word, dtype: object8.16e-02    1.01e-02
# 53902    philharmonic
# Name: word, dtype: object4.96e-02    3.27e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 21: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 90544    law
# Name: word, dtype: object9.52e-02    8.35e-03
# 16107    court
# Name: word, dtype: object6.84e-02    5.24e-03
# 84519    judge
# Name: word, dtype: object4.59e-02    4.44e-03
# 3672    attorney
# Name: word, dtype: object3.74e-02    4.30e-03
# 78624    district
# Name: word, dtype: object3.72e-02    4.20e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 22: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 9679    football
# Name: word, dtype: object1.21e-01    6.14e-03
# 20766    afl
# Name: word, dtype: object9.58e-02    1.31e-02
# 47558    australian
# Name: word, dtype: object7.91e-02    1.58e-03
# 91361    club
# Name: word, dtype: object5.93e-02    1.76e-03
# 47777    season
# Name: word, dtype: object5.58e-02    1.83e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 23: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 60567    research
# Name: word, dtype: object5.70e-02    2.68e-03
# 63664    science
# Name: word, dtype: object3.50e-02    2.95e-03
# 5424    university
# Name: word, dtype: object3.34e-02    7.14e-04
# 12363    professor
# Name: word, dtype: object3.20e-02    1.26e-03
# 98398    physics
# Name: word, dtype: object2.61e-02    5.43e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 24: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 47522    baseball
# Name: word, dtype: object1.16e-01    5.57e-03
# 30563    league
# Name: word, dtype: object1.03e-01    3.63e-03
# 89009    major
# Name: word, dtype: object5.09e-02    1.19e-03
# 84376    games
# Name: word, dtype: object4.66e-02    1.93e-03
# 53883    sox
# Name: word, dtype: object4.55e-02    6.28e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====

# %%
a = map_index_to_word[map_index_to_word['index'] == 0]

# %%
print a['word']
# Out:
# 35450    conflating
# Name: word, dtype: object

# %%
np.random.seed(5)
num_clusters = len(means)
num_docs, num_words = tf_idf.shape

random_means = []
random_covs = []
random_weights = []

for k in range(num_clusters):
    
    # Create a numpy array of length num_words with random normally distributed values.
    # Use the standard univariate normal distribution (mean 0, variance 1).
    # YOUR CODE HERE
    mean = np.random.normal(loc = 0.0, scale = 1.0, size = num_words)
    
    # Create a numpy array of length num_words with random values uniformly distributed between 1 and 5.
    # YOUR CODE HERE
    cov = np.random.uniform(low = 1.0, high = 5.0, size = num_words)
    # Initially give each cluster equal weight.
    # YOUR CODE HERE
    weight = 1.0 / num_clusters
    
    random_means.append(mean)
    random_covs.append(cov)
    random_weights.append(weight)

# %%
out_random_init = EM_for_high_dimension(tf_idf, means, covs, weights, cov_smoothing=1e-5)
print out_random_init['loglik']
# Out:
# [3855847476.6997027, 2362779935.0100083]

# %%
print out_random_init['loglik'][-1] - out['loglik'][-1]
# Out:
# -2481273267.45

# %%
visualize_EM_clusters(tf_idf, out_random_init['means'], out_random_init['covs'], 
                      map_index_to_word)
# Out:
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 35365    minister
# Name: word, dtype: object7.47e-02    7.40e-03
# 9571    election
# Name: word, dtype: object5.85e-02    3.23e-03
# 55669    party
# Name: word, dtype: object5.85e-02    2.62e-03
# 78889    elected
# Name: word, dtype: object2.89e-02    9.13e-04
# 12737    liberal
# Name: word, dtype: object2.89e-02    4.50e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 1: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 82263    film
# Name: word, dtype: object1.70e-01    6.80e-03
# 30008    films
# Name: word, dtype: object5.33e-02    2.98e-03
# 90293    festival
# Name: word, dtype: object4.53e-02    3.55e-03
# 74657    feature
# Name: word, dtype: object3.58e-02    1.80e-03
# 45729    directed
# Name: word, dtype: object3.29e-02    2.20e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 2: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 99041    art
# Name: word, dtype: object1.16e-01    7.43e-03
# 93543    museum
# Name: word, dtype: object5.17e-02    6.86e-03
# 55473    gallery
# Name: word, dtype: object3.32e-02    3.21e-03
# 38377    artist
# Name: word, dtype: object3.32e-02    1.41e-03
# 23104    design
# Name: word, dtype: object3.20e-02    4.40e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 3: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 24890    basketball
# Name: word, dtype: object1.60e-01    1.07e-02
# 98665    nba
# Name: word, dtype: object8.66e-02    1.17e-02
# 88378    points
# Name: word, dtype: object5.42e-02    5.52e-03
# 84674    coach
# Name: word, dtype: object4.91e-02    5.39e-03
# 62861    team
# Name: word, dtype: object4.17e-02    1.35e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 4: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 63206    hockey
# Name: word, dtype: object2.04e-01    2.20e-02
# 9243    nhl
# Name: word, dtype: object1.30e-01    1.71e-02
# 22075    ice
# Name: word, dtype: object5.34e-02    3.05e-03
# 47777    season
# Name: word, dtype: object4.21e-02    2.46e-03
# 30563    league
# Name: word, dtype: object3.94e-02    1.78e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 5: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 61450    republican
# Name: word, dtype: object7.04e-02    5.22e-03
# 26816    senate
# Name: word, dtype: object4.82e-02    5.84e-03
# 72895    house
# Name: word, dtype: object4.27e-02    2.35e-03
# 78624    district
# Name: word, dtype: object4.07e-02    2.32e-03
# 37414    democratic
# Name: word, dtype: object4.01e-02    2.87e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 6: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 17954    she
# Name: word, dtype: object1.58e-01    4.53e-03
# 26108    her
# Name: word, dtype: object1.00e-01    3.18e-03
# 42120    miss
# Name: word, dtype: object2.12e-02    7.19e-03
# 49188    women
# Name: word, dtype: object1.39e-02    1.37e-03
# 86159    womens
# Name: word, dtype: object1.16e-02    1.28e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 7: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 3119    championships
# Name: word, dtype: object7.36e-02    5.16e-03
# 43851    olympics
# Name: word, dtype: object4.58e-02    2.56e-03
# 69795    m
# Name: word, dtype: object4.41e-02    7.26e-03
# 91133    medal
# Name: word, dtype: object4.02e-02    2.41e-03
# 19114    olympic
# Name: word, dtype: object3.95e-02    2.48e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 8: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 49788    book
# Name: word, dtype: object1.45e-02    9.55e-04
# 45083    published
# Name: word, dtype: object1.24e-02    6.09e-04
# 10530    novel
# Name: word, dtype: object1.21e-02    1.65e-03
# 91574    that
# Name: word, dtype: object1.08e-02    1.78e-04
# 68168    he
# Name: word, dtype: object1.01e-02    6.99e-05
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 9: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 17954    she
# Name: word, dtype: object1.28e-01    4.95e-03
# 26108    her
# Name: word, dtype: object8.39e-02    3.00e-03
# 13971    actress
# Name: word, dtype: object6.99e-02    4.39e-03
# 82263    film
# Name: word, dtype: object5.51e-02    3.40e-03
# 96025    drama
# Name: word, dtype: object4.60e-02    6.06e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 10: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 10706    soccer
# Name: word, dtype: object1.05e-01    2.70e-02
# 43758    chess
# Name: word, dtype: object4.75e-02    1.70e-02
# 62861    team
# Name: word, dtype: object3.79e-02    2.09e-03
# 30563    league
# Name: word, dtype: object2.80e-02    1.91e-03
# 84674    coach
# Name: word, dtype: object2.80e-02    4.13e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 11: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 31012    president
# Name: word, dtype: object2.48e-02    1.27e-03
# 23416    chairman
# Name: word, dtype: object2.37e-02    1.94e-03
# 80967    committee
# Name: word, dtype: object2.28e-02    2.33e-03
# 82160    served
# Name: word, dtype: object2.21e-02    6.95e-04
# 96787    executive
# Name: word, dtype: object2.09e-02    1.22e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 12: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 49935    music
# Name: word, dtype: object7.11e-02    3.50e-03
# 10135    jazz
# Name: word, dtype: object5.94e-02    1.13e-02
# 3177    hong
# Name: word, dtype: object3.70e-02    9.74e-03
# 63008    kong
# Name: word, dtype: object3.42e-02    8.48e-03
# 85453    chinese
# Name: word, dtype: object3.06e-02    5.24e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 13: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 5424    university
# Name: word, dtype: object3.44e-02    8.88e-04
# 84644    history
# Name: word, dtype: object3.32e-02    2.78e-03
# 70803    philosophy
# Name: word, dtype: object2.80e-02    5.27e-03
# 12363    professor
# Name: word, dtype: object2.74e-02    1.08e-03
# 79811    studies
# Name: word, dtype: object2.40e-02    1.93e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 14: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 94850    theatre
# Name: word, dtype: object4.91e-02    6.16e-03
# 62782    actor
# Name: word, dtype: object3.55e-02    2.91e-03
# 28839    television
# Name: word, dtype: object3.20e-02    1.68e-03
# 82263    film
# Name: word, dtype: object2.92e-02    1.17e-03
# 2399    comedy
# Name: word, dtype: object2.85e-02    3.90e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 15: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 28764    album
# Name: word, dtype: object6.76e-02    4.77e-03
# 77923    band
# Name: word, dtype: object5.26e-02    4.00e-03
# 49935    music
# Name: word, dtype: object4.13e-02    1.92e-03
# 91242    released
# Name: word, dtype: object3.12e-02    1.12e-03
# 90519    song
# Name: word, dtype: object2.50e-02    1.84e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 16: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 7178    tour
# Name: word, dtype: object9.89e-02    1.80e-02
# 83391    pga
# Name: word, dtype: object9.29e-02    2.42e-02
# 85511    racing
# Name: word, dtype: object7.37e-02    7.84e-03
# 98586    championship
# Name: word, dtype: object5.37e-02    4.38e-03
# 38225    formula
# Name: word, dtype: object5.19e-02    1.17e-02
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 17: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 59421    news
# Name: word, dtype: object5.45e-02    7.76e-03
# 84292    radio
# Name: word, dtype: object4.90e-02    4.50e-03
# 32087    show
# Name: word, dtype: object3.70e-02    2.59e-03
# 99993    bbc
# Name: word, dtype: object3.42e-02    7.06e-03
# 80136    chef
# Name: word, dtype: object3.07e-02    1.12e-02
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 18: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 9679    football
# Name: word, dtype: object9.87e-02    6.18e-03
# 38050    yards
# Name: word, dtype: object6.58e-02    1.59e-02
# 24065    nfl
# Name: word, dtype: object6.23e-02    8.64e-03
# 84674    coach
# Name: word, dtype: object6.01e-02    7.45e-03
# 6336    quarterback
# Name: word, dtype: object3.59e-02    6.56e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 19: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 30563    league
# Name: word, dtype: object5.11e-02    3.13e-03
# 91361    club
# Name: word, dtype: object4.94e-02    2.64e-03
# 47777    season
# Name: word, dtype: object4.68e-02    2.31e-03
# 69500    rugby
# Name: word, dtype: object4.27e-02    8.07e-03
# 57957    cup
# Name: word, dtype: object4.15e-02    2.45e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 20: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 87468    orchestra
# Name: word, dtype: object1.16e-01    1.09e-02
# 49935    music
# Name: word, dtype: object1.11e-01    6.71e-03
# 74611    symphony
# Name: word, dtype: object7.80e-02    1.03e-02
# 47567    conductor
# Name: word, dtype: object7.19e-02    9.54e-03
# 22454    opera
# Name: word, dtype: object4.82e-02    8.95e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 21: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 90544    law
# Name: word, dtype: object8.62e-02    8.25e-03
# 16107    court
# Name: word, dtype: object6.37e-02    4.98e-03
# 84519    judge
# Name: word, dtype: object4.19e-02    4.17e-03
# 3672    attorney
# Name: word, dtype: object3.36e-02    4.00e-03
# 78624    district
# Name: word, dtype: object3.35e-02    3.91e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 22: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 9679    football
# Name: word, dtype: object1.15e-01    6.49e-03
# 20766    afl
# Name: word, dtype: object9.06e-02    1.29e-02
# 47558    australian
# Name: word, dtype: object7.68e-02    1.71e-03
# 91361    club
# Name: word, dtype: object5.61e-02    1.86e-03
# 47777    season
# Name: word, dtype: object5.28e-02    1.90e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 23: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 60567    research
# Name: word, dtype: object5.67e-02    2.69e-03
# 63664    science
# Name: word, dtype: object3.49e-02    2.95e-03
# 5424    university
# Name: word, dtype: object3.33e-02    7.24e-04
# 12363    professor
# Name: word, dtype: object3.18e-02    1.27e-03
# 98398    physics
# Name: word, dtype: object2.59e-02    5.42e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
# Cluster 24: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 47522    baseball
# Name: word, dtype: object1.15e-01    5.76e-03
# 30563    league
# Name: word, dtype: object1.01e-01    3.73e-03
# 89009    major
# Name: word, dtype: object4.99e-02    1.22e-03
# 84376    games
# Name: word, dtype: object4.59e-02    1.93e-03
# 53883    sox
# Name: word, dtype: object4.47e-02    6.18e-03
#
# =====================================================Quiz Question. Select all the topics that have a cluster in the model created above. [multiple choice]====
